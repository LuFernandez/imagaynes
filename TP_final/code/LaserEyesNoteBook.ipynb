# %%
# %pip install opencv-contrib-python --upgrade

# %%
# %run main.py
# Out:
# BackGroung Brightness = 82.86178059895833
# Face Brightness = 46.5734778180172
# Left side Brightness = 66.2242530556813
# Right side Brightness = 26.9227025803531
# BackGroung Brightness = 82.86178059895833
# Face Brightness = 46.5734778180172
# Left side Brightness = 66.2242530556813
# Right side Brightness = 26.9227025803531
# BackGroung Brightness = 101.356748046875
# Face Brightness = 63.24435053724652
# Left side Brightness = 87.43577126281986
# Right side Brightness = 39.29728759677998
# BackGroung Brightness = 101.356748046875
# Face Brightness = 63.24435053724652
# Left side Brightness = 87.43577126281986
# Right side Brightness = 39.29728759677998
# BackGroung Brightness = 101.62192057291666
# Face Brightness = 63.12320841551611
# Left side Brightness = 87.49505683320116
# Right side Brightness = 39.00005232862376
# BackGroung Brightness = 101.62192057291666
# Face Brightness = 63.12320841551611
# Left side Brightness = 87.49505683320116
# ...
